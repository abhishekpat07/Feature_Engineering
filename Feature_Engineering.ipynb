# %% [markdown]
# #1. What is a parameter?
# - A set o facts or a fixed limit that established or limits how something can or must happen or be done.

# %% [markdown]
# #2. What is correlation? What does negative correlation mean?
# - A correlation is statistical measure that describes the relationship between two variables. Negative correlation means that when one variable increase, the other varoable decreases.

# %% [markdown]
# #3. Define Machine Learning. What are the main components in Machine Learning?
# - Machine learning is a type of artificial intrlligence that enables machines to learn and perform tasks autonomously. The main components in Machine learning are: Representation, Evaluation and Optimization.

# %% [markdown]
# #4. How does loss value help in determining whether the model is good or not?
# - A lower loss value indicates a better performing model because it signifies that the model's predictions are closer to the actual values, meaning it makers fewer errors.

# %% [markdown]
# #5. What are continuous and categorical variables?
# - A continuous variable is a variable that can take on any value within a define range like height or temperature while a categorical variable is a variable that can take on alimited nummber of distinct categories or groups like gender, hair color or blood type.

# %% [markdown]
# #6. How do we handle categorical variables in Machine Learning? What are the common techniques?
# - In Machine learning, binary encoding vs one-hot encoding are essential techniques for handling categorical data.
# One-Hot Encoding is the most commonly used method. It creates new binary columns for each category/lebal present in the original data.

# %% [markdown]
# #7. What do you mean by training and testing a dataset?
# - Trainig data is used to teach a machine learning model, while testing data is used to evaluate the model's performance.

# %% [markdown]
# #8. What is sklearn.preprocessing?
# - Sklearn.preprocessing is module in the scikit-learn library in Python that provides functions and classes to transform raw data into a suitable format for machine learining algorithms.

# %% [markdown]
# #9. What is a Test set?
# - The test set is a portion of teh available training data that is held back and not used during model training.

# %% [markdown]
# #10. How do we split data for model fitting (training and testing) in Python?How do you approach a Machine Learning problem?
# - train_test_split() is function in sklearn that divides datatsets into training and testing subsets.
# - To approach a machine learning problem, following process invoving:
# 1. Defining the problem
# 2. Collecting relevant data
# 3. Cleaning and preparing the data
# 4. Selecting an approprizte machine learnign model, training the model on the data
# 5. evaluating its performance
# 6. deploying the model for prediction

# %% [markdown]
# #11. Why do we have to perform EDA before fitting a model to the data?
# - Perform EDA before fitting a model to data is crucial beacuse it allows you to understand the structure, patterns, and potential issues within your dataset.

# %% [markdown]
# #12. What is correlation?
# - A correlation is statistical measure that describes the relationship between two variables.

# %% [markdown]
# #13. What does negative correlation mean?
# - Negative correlation means that when one variable increase, the other varoable decreases.

# %% [markdown]
# #14. How can you find correlation between variables in Python?
# - In python, determine the correlation between variables using various methods such as correation matrix, heatmap visualization, scatter plots, spearmen and kendall correlation.

# %% [markdown]
# #15. What is causation? Explain difference between correlation and causation with an example.
# - Causation means that one event directly causes another to happen, establishing a clear cause-and- effect realtionship, while correlation simply indicates that two evenets occur togeather, without necessarily proving that one cause the other.
# Example:
# Correlation: Ice cream sales and crime rates often incease during the sumeer months, meaning they are correlated.
# Causation: Turning on a light switch directly causes the light to turn on.

# %% [markdown]
# #16. What is an Optimizer? What are different types of optimizers? Explain each with an example.
# - Optimizer are mathematical functions which are depandent on model's learnable parametere i.e Weights & Biases.
# Types of optimizers:
# 1. Gradient Descent
# 2. Stochastic Gradient Descent
# 3. Adagrad
# 4. Adadelta
# 5. RMSprop
# 6. Adam

# %% [markdown]
# #17. What is sklearn.linear_model ?
# - sklearn.linear_model is module in the scikit-learn library in Pythin that implements a variety of linesr models for regression, classification and other machine learning tasks.

# %% [markdown]
# #18. What does model.fit() do? What arguments must be given?
# - model.fit () is method used to train a machine learning model by adjesting its internal parameters to best fit the provided training data.
# Basic syntax for the fit() method is:
# model.fit (x, y)

# %% [markdown]
# #19. What does model.predict() do? What arguments must be given?
# - model.predict () is function used to generate predications on new data using a trained model.

# %% [markdown]
# #20. What are continuous and categorical variables?
# - A continuous variable is a variable that can take on any value within a define range like height or temperature while a categorical variable is a variable that can take on alimited nummber of distinct categories or groups like gender, hair color or blood type

# %% [markdown]
# #21. What is feature scaling? How does it help in Machine Learning?
# - Feature scaling is a vital pre processing step in machine learning that involves transforming numerical feartures to a common scale. It plays a major role in ensuring accurate and efficient model training and performance.

# %% [markdown]
# #22. How do we perform scaling in Python?
# - Perform feature scaling in Python using the scikit-learn library.

# %% [markdown]
# #23. What is sklearn.preprocessing?
# - Sklearn.preprocessing is module in the scikit-learn library in Python that provides functions and classes to transform raw data into a suitable format for machine learining algorithms.

# %% [markdown]
# #24. How do we split data for model fitting (training and testing) in Python?
# - train_test_split() is function in sklearn that divides datatsets into training and testing subsets.

# %% [markdown]
# #25. Explain data encoding?
# - Data encoding is the process of converting data into a specific format so that it can be stored, transmitted, and processess by computers.

# %%
#21.
